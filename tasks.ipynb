# %% [markdown]
# # Principles of Data Analytics – Assignment Notebook

# %% [markdown]
# # Task 1: Source the Data Set
# Datasets

# %%
# Import    

# dataframes 
import pandas as pd
# machine Learning Library that contains datasets.
import sklearn as skl 
# numerical package in Python
import numpy as np
# import plot package
import matplotlib.pyplot as plt
# import 
import seaborn as sns
# scientific computing
import scipy as sp
# import stats package 
from scipy import stats

# %%
# Load the iris dataset from sklearn library
from sklearn.datasets import load_iris

# the load_iris return the iris dataset 
# the as_frame parameter if True, the data is a pandas DataFrame including columns
# I used the documentation through the link below to learn more about parameters
# Reference 1.1: https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html
data = load_iris(as_frame=True)

# using df instead of data.frame to simplify the reading.
df = data.frame
# show dataframe
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %% [markdown]
# -   What does the load_iris() function returns?
#
#     The load_iris() function returns the iris dataset.
#     It's a sort of a dictionnary that shows all the dataset information. It lists the Data istelf and other grouped information linked to it
#     (example : target values, the feature names, and the target names etc..)

# %% [markdown]
# # Task 2: Explore the Data Structure

# %% [markdown]
# - Print and explain the data shape ?
# The data shape describes how the data is organised in terms of rows and columns
# the shape of Iris dataset consists of 4 columns and corresponding 150 rows.

# %%
# Shape of data returns a tuple representing the dimensionality of the dataframe.
data['data'].shape
# Out:
# (150, 4)

# %% [markdown]
# - Print and explain the features names?
# the features names returns the columns names
# 'sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)'

# %%
# features names function returns a list of names/titles of the dataset columns.              
data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# - Print and explain the target classes ?
# 3 Target index from 0 to index 2, these targets correspond to 3 iris classes / Species in order :
# 1st is Setosa, 2nd is Versicolor then 3rd is Virginica.

# %%
# classification target.
data['target']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64

# %%
# show target names           
data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# - Print and explain the first 5 rows of data ?
#     The first 5 rows of data show **Setosa** species -  which is corresponding to array 0 (see target and target_names)-.
#     This data head also shows the classe features, which are *sepal length (cm)', 'sepal width (cm)', 'petal length (cm)','petal width (cm)'* ( see features_name cell)

# %%
# the first 5 rows of dataset
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# - Print and explain the last 5 rows of data ?
#     The last 5 rows of data show **virginica** species -  which is corresponding to array 2 (see target and target_names)-.
#     This data head also shows the classe features ,which are *sepal length (cm)', 'sepal width (cm)', 'petal length (cm)','petal width (cm)'* ( see features_name cell)

# %%
# the last 5 rows of dataset
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %% [markdown]
# # Task 3: Summarize the Data

# %% [markdown]
# Calculating and displaying the following values for each feature in the dataset
# *mean * minimum * maximum * standard deviation * median

# %% [markdown]
# ### Mean :
# *'The sample mean, also called the sample arithmetic mean or simply the
# average, is the arithmetic average of all the items in a dataset.
# The mean of a dataset is the sum of all the elements divided by the
# number of items in the dataset.'*
#
# Source **Realpython**
# https://realpython.com/python-statistics/

# %%
# dataset description : lecture material and the link below, helped me take a new apprach to calculate the dataset features values. df.describe is also an option
# Reference 3.1: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html#:~:text=or%20Dataframe%20provided.-,See%20also,-DataFrame.count
# mean
df.mean()
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# target               1.000000
# dtype: float64

# %%
# minimum
df.min()
# Out:
# sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# target               0.0
# dtype: float64

# %%
# maximum
df.max()
# Out:
# sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# target               2.0
# dtype: float64

# %%
# standard deviation
df.std()
# Out:
# sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# target               0.819232
# dtype: float64

# %%
# median
df.median()
# Out:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# target               1.00
# dtype: float64

# %% [markdown]
# # Task 4: Visualize Features
#
# * Plot histograms for each feature using matplotlib ?
# * Add titles and labels.

# %%
# recalling features names 
data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
# assigning a value for each feature name for easy use later in plots.
sepal_length = data.data['sepal length (cm)']
sepal_width  = data.data['sepal width (cm)']
petal_length = data.data['petal length (cm)']
petal_width = data.data['petal width (cm)']

# %%
# calling a figure and set of axis within this figure: ploting a grid of 4 axis in one figure. 

# through the following links I was able to understand the subplot grid ,sharex, sharey and layout parameters. 
#  matplotlib documentation of the function allowing me to create figures and a grid of Axes
#  https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#:~:text=nrows%2C%20ncolsint,the%20subplot%20grid.

# sharey is now set to True which will allow Y axis to be shared among all plots.  
# reference 4.1 : https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html#:~:text=the%20subplot%20grid.-,sharex%2C%20sharey,-bool%20or%20%7B%27none

# Constrained layout is set to False, not very convinced otf the layout, I did replace it at the end of the cell by subplots_adjust, it allowed me to better manage the plots.
# Reference 4.2 : https://matplotlib.org/stable/users/explain/axes/constrainedlayout_guide.html#manually-turning-off-constrained-layout
# Reference 4.3 : https://matplotlib.org/3.1.0/tutorials/intermediate/constrainedlayout_guide.html ( older version of documentation)


# set a group of subplots with grid(2,2)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, sharex=False, constrained_layout=False, sharey=True,  figsize=(14,8))


# histograms for each feature

# ax1 : plot histogram
ax1.hist(sepal_length, ec= "k", color='b',alpha=0.6)
# adding labels
ax1.set_xlabel("Sepal length in cm", fontsize=12)
ax1.set_ylabel("count",fontsize=10, color="k")

# ax2 : plot histogram
ax2.hist(sepal_width,ec= "k", color='g', alpha=0.6)
# adding labels
ax2.set_xlabel("Sepal width in cm", fontsize=12)
ax2.set_ylabel("count", color="k")


# ax3: plot histogram
ax3.hist(petal_length,ec= "k", color='m', alpha=0.5)
# adding labels
ax3.set_xlabel("Petal length in cm", fontsize=12)
ax3.set_ylabel("count", color="k")

# ax4: plot histogram
ax4.hist(petal_width,ec= "k", color='y',  alpha=0.5)
# adding labels
ax4.set_xlabel("petal width in cm", fontsize=12)
ax4.set_ylabel("count", color="k")


# using 'hspace =' is a subplots_adjust layout parameter, this helped me control the height of the padding between subplots. 
# Reference 4.4 : https://matplotlib.org/stable/api/_as_gen/matplotlib.figure.Figure.subplots_adjust.html
plt.subplots_adjust(hspace=0.3)

# adding dataset suptitle, using a line break 
# https://stackoverflow.com/questions/21967639/how-to-write-a-plot-title-in-more-than-one-line-using-suptitle
plt.suptitle("Iris dataset\nExploring Each Feature with a Histogram", fontsize=18, color="g", alpha=0.5)
# Out:
# Text(0.5, 0.98, 'Iris dataset\nExploring Each Feature with a Histogram')

# %% [markdown]
# # Task 5: Investigate Relationships
#
# * Choose any two features from the data set and create a scatter plot of them.
# * Color-code the three different classes of the scatter plot points.

# %%
# scatter plot of both Sepal length and Sepal width from the Iris dataset. 

# recall features names 

sepal_length = data.data['sepal length (cm)']
sepal_width  = data.data['sepal width (cm)']
petal_length = data.data['petal length (cm)']
petal_width = data.data['petal width (cm)']

# create figure and axis
fig, ax = plt.subplots()

# recalling dataset classes for color differenciation purposes
classes = data['target']


# adding a grid to simplify dataset features reading. Followed the link-below to learn more about the grid function.
# Reference 5.1 : https://www.w3schools.com/python/matplotlib_grid.asp
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.05)

# through the link below, I was able to learn more about the color palette. 
# Reference 5.2: https://matplotlib.org/stable/users/explain/colors/colors.html

# set a title and labels
plt.title('Scatter plot of Sepal Width vs Sepal Length across all three Iris species', c='black', fontsize=15, alpha=0.6)

ax.set_xlabel('sepal width in cm')
ax.set_ylabel('sepal length in cm')

# I used subplots_adjust to help medjust the subplot layout parameters  
# Reference 5.3 : https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots_adjust.html
plt.subplots_adjust(right=1.4, top=1.3)

# assigning a variable called scatter 
scatter = ax.scatter(sepal_width, sepal_length,c=classes, marker='.')

# adding a legend in order to distinguish the 3 different species, and, making sure the legend's location is put in an empty part of the plot. 
ax.legend(scatter.legend_elements()[0], data['target_names'], loc="lower right", title=" iris Species", fontsize=12)

# %% [markdown]
# # Task 6: Analyze Relationship
# * Use numpy.polyfit to add a regression line to the scatter plot from Task 5.

# %%
# recall the scatter plot method implemented in task 5 
fig, ax = plt.subplots()
scatter = ax.scatter(sepal_width, sepal_length, label='Iris flowers', c=classes, marker='.')

# adding a grid to simplify dataset features reading. 
plt.grid(color = 'blue', linestyle = '--', linewidth = 0.06)

# Use polyfit to fit a line to the data.
np.polyfit(sepal_width, sepal_length, 1)

# y = mx + c, where m is the slope and c is the y-intercept
m, c = np.polyfit(sepal_width, sepal_length, deg=1)

# plot
plt.plot(sepal_width, m * sepal_width + c, label=' Fit line', color = 'grey')

# set a title and labels
plt.title('Scatter plot of Sepal Width vs Sepal Length across all three Iris species', c='black', fontsize=15, alpha=0.6)
ax.set_xlabel('sepal width in cm')
ax.set_ylabel('sepal length in cm')

# I used subplots_adjust to help medjust the subplot layout parameters  
plt.subplots_adjust(right=1.4, top=1.3)

# adding a legend and place in upper light of the plot
legend_1 = ax.legend(loc="upper right")

# %% [markdown]
# *   !! **IN PROGRESS** : still exploring the documentation, took note of main method and parameters frrom module lecture.
# I need to retrieve petal length across species and use the vaues for a boxplot.
#
# ## Task 7: Analyze Class Distributions
# * Create box-plots of the petal lengths for each of the three classes.

# %%
# access each specie using the np array method
# load the dataset 
data = load_iris()
# data['target_names'] is an array, so I identified the species as follow

# Iris species
#setosa      = data['target_names']== 0
#versicolor  = data['target_names']== 1
#virginica   = data['target_names']== 2

# petal length of each Iris specie. accessing each specie using the np array 
# Course material + mthod of Indexing on ndarrays Numpy documentation.
# reference 7.1 : https://numpy.org/doc/stable/user/basics.indexing.html

setosa_petal_length     = data['data'][data['target'] == 0,2]
versicolor_petal_length = data['data'][data['target'] == 1,2]
virginica_petal_length  = data['data'][data['target'] == 2,2]

# Create figure, axis
fig, ax = plt.subplots()

# assign a variable 
species_petal_length = np.array([setosa_petal_length, versicolor_petal_length, virginica_petal_length])

# create boxplot
ax.boxplot(species_petal_length.T);

# set names of x-axis ticks.
# Course material  'boxplots' + the following link to documentation page
# # reference 7.2 https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticks.html
ax.set_xticks([1, 2, 3], [" Setosa ", " Versicolor ", "Virginica"], fontsize=10)

# adjust y ticks to 0.5 step
minor_ticks = np.arange(0, 10, 0.5)
ax.set_yticks(minor_ticks, minor=True)

# set axis labels
plt.xlabel('Iris Species', labelpad=20)
plt.ylabel('Petal length in cm')

# add figure title
plt.suptitle('  Side-by-Side Boxplots')
plt.title('Petal length of 3 Iris Species', c='chocolate', fontsize= 12,  y=1.03, weight ='normal')

# add different settings for the grids
ax.grid(which='minor', alpha=0.3, linestyle ='--')
ax.grid(which='major', alpha=0.2)

# adjust the subplot layout using parameters
# refrence 7.3: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots_adjust.html
plt.subplots_adjust(hspace=0.8)
plt.grid()

# %% [markdown]
# ## Task 8: Compute Correlations
# *   Calculate the correlation coefficients between the features.
# *   Display the results as a heatmap using matplotlib.

# %% [markdown]
# *Correlations is how one variable changes as the other changes.*
#
# This measure ranges from negative one to one.
# *Negative one (-1) indicates* a strong negative relationship (as one variable increases, the other decreases)
# *One(1) indicates* a strong positive relationship (as one variable increases, the other also increases)
# Zero indicates no relationship (the change of one variable is not related to the change of the other)
#
# Sourece : https://campus.datacamp.com/courses/introduction-to-python-in-power-bi/heatmaps-and-correlation-coefficients?ex=1

# %%
# calculate the correlation coefficients between the features

# resources used to research the the definition, the purpose and calculation and the method before starting the code
# reference 8.1: https://campus.datacamp.com/courses/introduction-to-python-in-power-bi/heatmaps-and-correlation-coefficient
# reference 8.2: https://www.geeksforgeeks.org/create-a-correlation-matrix-using-python/
# analyze relationships between dataset features through the correlation coefficients then with Seaborn heatmaps.

# load dataset
data = load_iris()
# columns
columns=data['feature_names']
# data frame
df = pd.DataFrame(data.data, columns=data['feature_names'])

# matrix
corrMatrix = df.corr()
# fig, axis
fig, ax = plt.subplots(figsize=(7, 5))

# plot correlation matrix
# reference 8.3: https://matplotlib.org/stable/users/explain/colors/colormaps.html
plt.imshow(corrMatrix, cmap='YlOrBr')

# display ticks and add labels
# this source 
# reference 8.4: https://hyperskill.org/learn/step/17677

# set x tick labels 
ax.set_xticks(np.arange(len(corrMatrix.columns)),corrMatrix.columns, rotation=90) 
# set x tick labels 
ax.set_yticks(np.arange(len(corrMatrix.columns)),corrMatrix.columns, rotation=45) 


# add colorbar and set a label
plt.colorbar(label='Correlation')

# show
plt.show()

# %%
# calculate the correlation using Seaborn
# reference 8.5 : https://stackoverflow.com/questions/54506626/how-to-understand-seaborns-heatmap-annotation-format#:~:text=sns.heatmap(df.corr()%2Cannot%3DTrue%2Cfmt%3D%22.1f%22%2Cax%3Dax)

sns.heatmap(df.corr(), annot=True, cmap='YlOrBr', fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# ## Task 9: Fit a Simple Linear Regression !! ( calculation in progress)
# *   For 'Sepal width' & 'Sepal length' features in Task 5, calculate the coefficient of determination R2.

# %% [markdown]
# *' R2 is a measure of the goodness of fit of a model.
# In regression, the R2 coefficient of determination is a statistical measure of how well the regression predictions approximate the real data points.
# An R2 of 1 indicates that the regression predictions perfectly fit the data.'*
#
# Source **Wikipedia**
# https://en.wikipedia.org/wiki/Coefficient_of_determination#:~:text=R2%20is%20a%20measure,predictions%20perfectly%20fit%20the%20data.
#
# *'R square value (R2) is a regression error metric to evaluate the accuracy and efficiency of a model on the data values that it would be applied to.
# R2 helps determine how well the model is blend and how well the output value is explained by the determining(independent) variables of the dataset.'*
#
# Source **Askpython**
# https://www.askpython.com/python/coefficient-of-determination

# %%
# still reading the documentation and applyign the method proposed by my Lecturer, to calculate R2 both manually then using scipy.
# the logic behind this approach is to compare and see if scipy will be returning an accurate ro an appoximate value of R squared.

# %%
# calculate the coefficient of determination R2 using Scipy first
# the purpose of this approach is to verify the accuracy of the calculation by comparing the R2 calculated by scipy with the R2 calculated manually  

# scipy.stats.linregress is a function from the SciPy library that performs a linear least-squares regression for two sets of measurements.
# as I already imported scipy, I applied the method in the link below to calculate the coefficient of determination R2
# regerence 9.1 : https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html

# x is equivalent to 'Speal Width' and  is equivalent to 'Sepal Length', I previously assigned these values in Task 5.
slope, intercept, r, p, std_err = stats.linregress(sepal_width, sepal_length)

res = stats.linregress(sepal_width, sepal_length)
print(f"R-squared: {res.rvalue**2:.6f}")
# Out:
# R-squared: 0.013823
